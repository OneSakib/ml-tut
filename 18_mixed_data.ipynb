# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('data/titanic_updated.csv')
df.dropna(inplace=True)
df.head()
# Out:
#    Cabin    Ticket number  Survived
# 1    C85  PC 17599      3         1
# 3   C123    113803      3         1
# 6    E46     17463      2         0
# 10    G6   PP 9549      1         1
# 11  C103    113783      1         1

# %%
df['number'].unique()
# Out:
# array(['3', '2', '1', '4', 'A', '6', '5'], dtype=object)

# %%
fig=df['number'].value_counts().plot.bar()
plt.show()

# %%
df['number_numerical']=pd.to_numeric(df['number'],errors='coerce',downcast='integer')

# %%
df['number_categorical']=np.where(df['number_numerical'].isnull(),df['number'],np.nan)
df.head()
# Out:
#    Cabin    Ticket number  Survived  number_numerical number_categorical
# 1    C85  PC 17599      3         1               3.0                NaN
# 3   C123    113803      3         1               3.0                NaN
# 6    E46     17463      2         0               2.0                NaN
# 10    G6   PP 9549      1         1               1.0                NaN
# 11  C103    113783      1         1               1.0                NaN

# %%
df.sample(10)
# Out:
#            Cabin    Ticket number  Survived  number_numerical  \
# 716          C45  PC 17757      4         1               4.0
# 262          E67    110413      4         0               4.0
# 438  C23 C25 C27     19950      2         0               2.0
# 849          C92     17453      A         1               NaN
# 711         C124    113028      1         0               1.0
# 137         C123    113803      6         0               6.0
# 515          D46     36967      3         0               3.0
# 641          B35  PC 17477      2         1               2.0
# 645          D33  PC 17572      2         1               2.0
# 820          B69     12749      6         1               6.0
#
#     number_categorical
# 716                NaN
# 262                NaN
# 438                NaN
# 849                  A
# 711                NaN
# 137                NaN
# 515                NaN
# 641                NaN
# 645                NaN
# 820                NaN

# %%
df['Cabin'].unique()
# Out:
# array(['C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6', 'C23 C25 C27',
#        'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33', 'F G73', 'E31',
#        'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101', 'F E69', 'D47',
#        'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4', 'A32', 'B4',
#        'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35', 'C87', 'B77',
#        'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19', 'B49', 'D',
#        'C22 C26', 'C106', 'C65', 'E36', 'C54', 'B57 B59 B63 B66', 'C7',
#        'E34', 'C32', 'B18', 'C124', 'C91', 'E40', 'T', 'C128', 'D37',
#        'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44', 'A34', 'C104',
#        'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14', 'B37', 'C30',
#        'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38', 'B39', 'B22',
#        'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68', 'B41', 'A20',
#        'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48', 'E58', 'C126',
#        'B71', 'B51 B53 B55', 'D49', 'B5', 'B20', 'F G63', 'C62 C64',
#        'E24', 'C90', 'C45', 'E8', 'B101', 'D45', 'C46', 'D30', 'E121',
#        'D11', 'E77', 'F38', 'B3', 'D6', 'B82 B84', 'D17', 'A36', 'B102',
#        'B69', 'E49', 'C47', 'D28', 'E17', 'A24', 'C50', 'B42', 'C148'],
#       dtype=object)

# %%
df['Ticket'].unique()
# Out:
# array(['PC 17599', '113803', '17463', 'PP 9549', '113783', '248698',
#        '113788', '19950', 'PC 17569', 'PC 17572', '113509', '19947',
#        '113572', '36973', 'C.A. 29395', '348123', 'W.E.P. 5734',
#        'PC 17754', 'PC 17759', '35281', '110465', 'PC 17558', '27267',
#        '2668', '11752', 'PC 17593', '230080', '113776', '113505',
#        '111240', '17764', 'PC 17595', '230136', '113767', 'PC 17610',
#        '347054', '112277', '35273', '11813', '19943', '19928', '11751',
#        '113514', '110152', '110413', '112059', 'PC 17582', 'PC 17760',
#        'PC 17596', '13502', '113056', '11967', 'SC/Paris 2163', '113781',
#        '19988', '226593', 'PC 17758', 'PC 17485', '11767', 'PC 17608',
#        '36928', '16966', '28551', '111361', '113043', '113784', '248733',
#        '113510', '110813', 'PC 17477', '11765', '113503', '113760',
#        'SOTON/O.Q. 392078', '110564', '13507', '33638', '113786',
#        '113051', '17453', '13509', '17464', '19952', '111320',
#        'SC/AH Basle 541', '11771', '113787', '36947', 'PC 17473', '36967',
#        'C.A. 34260', '12749', 'PC 17483', '113050', '13568', 'WE/P 5735',
#        'PC 17761', '17421', '11755', '11769', 'PC 17474', '13049',
#        '13567', '11753', '36963', '27042', '13214', '13213', '5727',
#        '19996', 'F.C. 12750', 'PC 17755', '24160', '17474', '348121',
#        'PC 17757', 'PC 17475', 'PC 17476', 'PC 17482', '113028', '348124',
#        '34218', '113806', '16988', '19877', '113773', '392096',
#        'S.O./P.P. 3', '383121', '113501', '17465', '112050', '112058',
#        'PC 17756', '11774', 'PC 17592', '113055', '17466', 'PC 17590',
#        '695', '112053', '111369'], dtype=object)

# %%
df['cabin_num']=df['Cabin'].str.extract('(\d+)')
df['cabin_cat']=df['Cabin'].str.extract('(^\D+)')
df.head()
# Out:
#    Cabin    Ticket number  Survived  number_numerical number_categorical  \
# 1    C85  PC 17599      3         1               3.0                NaN
# 3   C123    113803      3         1               3.0                NaN
# 6    E46     17463      2         0               2.0                NaN
# 10    G6   PP 9549      1         1               1.0                NaN
# 11  C103    113783      1         1               1.0                NaN
#
#    cabin_num cabin_cat
# 1         85         C
# 3        123         C
# 6         46         E
# 10         6         G
# 11       103         C

# %%
df['cabin_cat'].value_counts().plot(kind='bar')
plt.show()

# %%
df['ticket_num']=df['Ticket'].apply(lambda s:s.split()[-1])
df['ticket_num']=pd.to_numeric(df['ticket_num'],errors="coerce",downcast="integer")


df['ticket_cat']=df['Ticket'].apply(lambda x: x.split()[0]) 
df['ticket_cat']=np.where(df['ticket_cat'].str.isdigit(),np.nan,df['ticket_cat'])

df.sample(20)
# Out:
#        Cabin           Ticket number  Survived  number_numerical  \
# 647      A26            13213      A         1               NaN
# 710      C90         PC 17482      5         1               5.0
# 473        D  SC/AH Basle 541      2         1               2.0
# 394       G6          PP 9549      6         1               6.0
# 128    F E69             2668      6         1               6.0
# 297  C22 C26           113781      5         0               5.0
# 62       C83            36973      6         0               6.0
# 716      C45         PC 17757      4         1               4.0
# 193       F2           230080      6         1               6.0
# 452     C111           113051      2         0               2.0
# 701      E24         PC 17475      5         1               5.0
# 796      D17            17465      4         1               4.0
# 434      E44            13507      3         0               3.0
# 751     E121           392096      5         1               5.0
# 356      E33           113505      1         1               1.0
# 630      A23            27042      6         1               6.0
# 248      D35            11751      4         1               4.0
# 393      D36            35273      1         1               1.0
# 307      C65         PC 17758      2         1               2.0
# 585      E68           110413      3         1               3.0
#
#     number_categorical cabin_num cabin_cat  ticket_num ticket_cat
# 647                  A        26         A       13213        NaN
# 710                NaN        90         C       17482         PC
# 473                NaN       NaN         D         541      SC/AH
# 394                NaN         6         G        9549         PP
# 128                NaN        69       F E        2668        NaN
# 297                NaN        22         C      113781        NaN
# 62                 NaN        83         C       36973        NaN
# 716                NaN        45         C       17757         PC
# 193                NaN         2         F      230080        NaN
# 452                NaN       111         C      113051        NaN
# 701                NaN        24         E       17475         PC
# 796                NaN        17         D       17465        NaN
# 434                NaN        44         E       13507        NaN
# 751                NaN       121         E      392096        NaN
# 356                NaN        33         E      113505        NaN
# 630                NaN        23         A       27042        NaN
# 248                NaN        35         D       11751        NaN
# 393                NaN        36         D       35273        NaN
# 307                NaN        65         C       17758         PC
# 585                NaN        68         E      110413        NaN
