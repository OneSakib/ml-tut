# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats
from sklearn.preprocessing import PowerTransformer
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score,accuracy_score

# %%
df=pd.read_csv('data/concrete_data.csv')
df
# Out:
#       Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0      540.0                 0.0      0.0  162.0               2.5
# 1      540.0                 0.0      0.0  162.0               2.5
# 2      332.5               142.5      0.0  228.0               0.0
# 3      332.5               142.5      0.0  228.0               0.0
# 4      198.6               132.4      0.0  192.0               0.0
# ...      ...                 ...      ...    ...               ...
# 1025   276.4               116.0     90.3  179.6               8.9
# 1026   322.2                 0.0    115.6  196.0              10.4
# 1027   148.5               139.4    108.6  192.7               6.1
# 1028   159.1               186.7      0.0  175.6              11.3
# 1029   260.9               100.5     78.3  200.6               8.6
#
#       Coarse Aggregate  Fine Aggregate  Age  Strength
# 0               1040.0           676.0   28     79.99
# ...

# %%
df.shape
# Out:
# (1030, 9)

# %%
df.isnull().sum()
# Out:
# Cement                0
# Blast Furnace Slag    0
# Fly Ash               0
# Water                 0
# Superplasticizer      0
# Coarse Aggregate      0
# Fine Aggregate        0
# Age                   0
# Strength              0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(25)

# %%
df.drop_duplicates(inplace=True)

# %%
x=df.drop(columns=['Strength'])
y=df['Strength']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=0.2)

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)
r2_score(y_test,y_pred)*100
# Out:
# 58.01703029028778

# %%
lr=LinearRegression()
np.mean(cross_val_score(lr,x,y,scoring="r2"))*100
# Out:
# np.float64(47.68001056283902)

# %%
# plotting the disptplot without transformationfro
for col in x_train.columns:
    plt.figure(figsize=(15,4))
    plt.subplot(121)
    sns.distplot(x_train[col])
    plt.title(col)
    plt.subplot(122)
    stats.probplot(x_train[col],dist='norm',plot=plt)
    plt.title(col)
    plt.show()
# Out:
# C:\Users\malik\AppData\Local\Temp\ipykernel_12092\3474541370.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x_train[col])
# C:\Users\malik\AppData\Local\Temp\ipykernel_12092\3474541370.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x_train[col])
# ...

# %%
# Apply Box-COX
pt=PowerTransformer(method="box-cox")
x_train_transformed=pt.fit_transform(x_train+0.0001)
x_test_transformed=pt.fit_transform(x_test+0.0001)
pd.DataFrame({'cols':x_train.columns,'box-cox_lamdas':pt.lambdas_})
x_train_transformed=pd.DataFrame(x_train_transformed,columns=x_train.columns)

# %%
# Apply linear regression after applied transformed
lr=LinearRegression()
lr.fit(x_train_transformed,y_train)
y_pred2=lr.predict(x_test_transformed)
r2_score(y_test,y_pred2)*100
# Out:
# c:\Users\malik\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 79.62334862576094

# %%
# Befre and after tansformatetion
for col in x_train.columns:
    plt.figure(figsize=(14,4))
    plt.subplot(121)
    stats.probplot(x_train[col],dist='norm',plot=plt)
    plt.title("Before "+col)
    plt.subplot(122)
    stats.probplot(x_train_transformed[col],dist='norm',plot=plt)
    plt.title("After "+col)
    plt.show()

# %%
# Apply Yeo Jonshan
pt=PowerTransformer()
x_train_transformed2=pt.fit_transform(x_train+0.0001)
x_test_transformed2=pt.fit_transform(x_test+0.0001)
pd.DataFrame({'cols':x_train.columns,'yeo_jonshaan':pt.lambdas_})
x_train_transformed2=pd.DataFrame(x_train_transformed2,columns=x_train.columns)

# %%
# Apply linear regression after applied transformed
lr=LinearRegression()
lr.fit(x_train_transformed2,y_train)
y_pred2=lr.predict(x_test_transformed2)
r2_score(y_test,y_pred2)*100
# Out:
# c:\Users\malik\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 79.62334862576094

# %%
# Befre and after tansformatetion
for col in x_train.columns:
    plt.figure(figsize=(14,4))
    plt.subplot(121)
    stats.probplot(x_train[col],dist='norm',plot=plt)
    plt.title("Before "+col)
    plt.subplot(122)
    stats.probplot(x_train_transformed2[col],dist='norm',plot=plt)
    plt.title("After "+col)
    plt.show()

# %%
# Apply cross val transger
pt=PowerTransformer()
lr=LinearRegression()
x_train_transformed2=pt.fit_transform(x)
np.mean(cross_val_score(lr,x_train_transformed2,y,scoring="r2"))*100
# Out:
# np.float64(69.38787274365762)
